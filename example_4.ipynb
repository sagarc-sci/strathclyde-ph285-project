# %%
# %run spectral_synthesis.py -p run-1 -x
# Out:
# /Users/sagar/Workspace/ph285-project/spectral_synthesis.py:722: RuntimeWarning: invalid value encountered in divide

# %%
# %run spectral_synthesis.py -p run-2 -x
# Out:
# /Users/sagar/Workspace/ph285-project/spectral_synthesis.py:722: RuntimeWarning: invalid value encountered in divide
