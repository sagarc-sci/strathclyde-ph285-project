# %%
# %run spectral_synthesis.py -p run-2
# Out:
# Sampled 5000000 photons; accepted 953407; required 1000000
# /Users/sagar/Workspace/ph285-project/spectral_synthesis.py:666: RuntimeWarning: invalid value encountered in divide
