# %%
# %run spectral_synthesis.py -p run-1 -x
# Out:
# /Users/sagar/Workspace/ph285-project/spectral_synthesis.py:1221: RuntimeWarning: invalid value encountered in divide
#   intensity_ratio = output_intensity / input_intensity

# %%
# %run spectral_synthesis.py -p run-2 -x
# Out:
# /Users/sagar/Workspace/ph285-project/spectral_synthesis.py:1221: RuntimeWarning: invalid value encountered in divide
#   intensity_ratio = output_intensity / input_intensity

# %%
# %run spectral_synthesis.py -p run-3 -x
# Out:
# /Users/sagar/Workspace/ph285-project/spectral_synthesis.py:1221: RuntimeWarning: invalid value encountered in divide
#   intensity_ratio = output_intensity / input_intensity

# %%
# %run spectral_synthesis.py -p run-4 -x
# Out:
# /Users/sagar/Workspace/ph285-project/spectral_synthesis.py:1221: RuntimeWarning: invalid value encountered in divide
#   intensity_ratio = output_intensity / input_intensity
