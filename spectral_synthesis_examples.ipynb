# %%
# %run spectral_synthesis.py -p runs/spherical-medium -x
# Out:
# /Users/sagar/Workspace/ph285-project/spectral_synthesis.py:1338: RuntimeWarning: invalid value encountered in divide
#   intensity_ratio = output_intensity / input_intensity

# %%
# %run spectral_synthesis.py -p runs/planar-medium -x
# Out:
# /Users/sagar/Workspace/ph285-project/spectral_synthesis.py:1338: RuntimeWarning: invalid value encountered in divide
#   intensity_ratio = output_intensity / input_intensity

# %%
# %run spectral_synthesis.py -p runs/spherical-fast -x -v
# Out:
# /Users/sagar/Workspace/ph285-project/spectral_synthesis.py:1338: RuntimeWarning: invalid value encountered in divide
#   intensity_ratio = output_intensity / input_intensity

# %%
# %run spectral_synthesis.py -p runs/planar-fast -x -v
# Out:
# /Users/sagar/Workspace/ph285-project/spectral_synthesis.py:1338: RuntimeWarning: invalid value encountered in divide
#   intensity_ratio = output_intensity / input_intensity
