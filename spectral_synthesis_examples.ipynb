# %%
# %run spectral_synthesis.py -p runs/spherical-medium -x

# %%
# %run spectral_synthesis.py -p runs/planar-medium -x

# %%
# %run spectral_synthesis.py -p runs/spherical-fast -x
# Out:
# /Users/sagar/Workspace/ph285-project/spectral_synthesis.py:1242: RuntimeWarning: invalid value encountered in divide
#   intensity_ratio = output_intensity / input_intensity

# %%
# %run spectral_synthesis.py -p runs/planar-fast -x
# Out:
# /Users/sagar/Workspace/ph285-project/spectral_synthesis.py:1242: RuntimeWarning: invalid value encountered in divide
#   intensity_ratio = output_intensity / input_intensity
